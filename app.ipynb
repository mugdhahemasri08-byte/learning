# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
pip install -U -q "google-genai"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
#import google.generativeai as genai
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="till what date you have data"
)
print(response.text)
# Out:
# My knowledge cutoff is not a precise date, but for the most part, my training data includes information up to **early 2023**.
#
# Therefore, I cannot provide real-time information or details about events that occurred very recently after that period. For the most current information, you should always consult up-to-date news sources or specific websites.

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        {"role": "system", "parts": "You are a helpful assistant that answers with examples."},
        {"role": "user", "parts": "Explain embeddings in simple words."}
    ]
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[20], line 5
#       1 from google import genai
#       3 client = genai.Client()
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash",
#       7     contents=[
#       8         {"role": "system", "parts": "You are a helpful assistant that answers with examples."},
#       9         {"role": "user", "parts": "Explain embeddings in simple words."}
#      10     ]
#      11 )
#      13 print(response.text)
#
# File /workspaces/test1/learning-env/lib/python3.12/site-packages/google/genai/models.py:5218, in Models.generate_content(self, model, contents, config)
#    5216 while remaining_remote_calls_afc > 0:
#    5217   i += 1
# -> 5218   response = self._generate_content(
#    5219       model=model, contents=contents, config=parsed_config
#    5220   )
#    5222   function_map = _extra_utils.get_function_map(parsed_config)
#    5223   if not function_map:
#
# File /workspaces/test1/learning-env/lib/python3.12/site-packages/google/genai/models.py:3958, in Models._generate_content(self, model, contents, config)
#    3951 def _generate_content(
#    3952     self,
#    3953     *,
#    (...)   3956     config: Optional[types.GenerateContentConfigOrDict] = None,
#    3957 ) -> types.GenerateContentResponse:
# -> 3958   parameter_model = types._GenerateContentParameters(
#    3959       model=model,
#    3960       contents=contents,
#    3961       config=config,
#    3962   )
#    3964   request_url_dict: Optional[dict[str, str]]
#    3966   if self._api_client.vertexai:
#
# File /workspaces/test1/learning-env/lib/python3.12/site-packages/pydantic/main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 28 validation errors for _GenerateContentParameters
# contents.Content
#   Input should be a valid dictionary or object to extract fields from [type=model_attributes_type, input_value=[{'role': 'system', 'part...ings in simple words.'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.12/v/model_attributes_type
# contents.str
#   Input should be a valid string [type=string_type, input_value=[{'role': 'system', 'part...ings in simple words.'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# contents.File
#   Input should be a valid dictionary or object to extract fields from [type=model_attributes_type, input_value=[{'role': 'system', 'part...ings in simple words.'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.12/v/model_attributes_type
# contents.Part
#   Input should be a valid dictionary or object to extract fields from [type=model_attributes_type, input_value=[{'role': 'system', 'part...ings in simple words.'}], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.12/v/model_attributes_type
# contents.list[union[str,File,Part]].0.str
#   Input should be a valid string [type=string_type, input_value={'role': 'system', 'parts...answers with examples.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# contents.list[union[str,File,Part]].0.File.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='system', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[str,File,Part]].0.File.parts
#   Extra inputs are not permitted [type=extra_forbidden, input_value='You are a helpful assist... answers with examples.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[str,File,Part]].0.Part.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='system', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[str,File,Part]].0.Part.parts
#   Extra inputs are not permitted [type=extra_forbidden, input_value='You are a helpful assist... answers with examples.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[str,File,Part]].1.str
#   Input should be a valid string [type=string_type, input_value={'role': 'user', 'parts':...dings in simple words.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# contents.list[union[str,File,Part]].1.File.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='user', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[str,File,Part]].1.File.parts
#   Extra inputs are not permitted [type=extra_forbidden, input_value='Explain embeddings in simple words.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[str,File,Part]].1.Part.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='user', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[str,File,Part]].1.Part.parts
#   Extra inputs are not permitted [type=extra_forbidden, input_value='Explain embeddings in simple words.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.Content.parts
#   Input should be a valid list [type=list_type, input_value='You are a helpful assist... answers with examples.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/list_type
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.str
#   Input should be a valid string [type=string_type, input_value={'role': 'system', 'parts...answers with examples.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.File.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='system', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.File.parts
#   Extra inputs are not permitted [type=extra_forbidden, input_value='You are a helpful assist... answers with examples.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.Part.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='system', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.Part.parts
#   Extra inputs are not permitted [type=extra_forbidden, input_value='You are a helpful assist... answers with examples.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].0.list[union[str,File,Part]]
#   Input should be a valid list [type=list_type, input_value={'role': 'system', 'parts...answers with examples.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/list_type
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.Content.parts
#   Input should be a valid list [type=list_type, input_value='Explain embeddings in simple words.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/list_type
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.str
#   Input should be a valid string [type=string_type, input_value={'role': 'user', 'parts':...dings in simple words.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.File.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='user', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.File.parts
#   Extra inputs are not permitted [type=extra_forbidden, input_value='Explain embeddings in simple words.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.Part.role
#   Extra inputs are not permitted [type=extra_forbidden, input_value='user', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.Part.parts
#   Extra inputs are not permitted [type=extra_forbidden, input_value='Explain embeddings in simple words.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# contents.list[union[Content,str,File,Part,list[union[str,File,Part]]]].1.list[union[str,File,Part]]
#   Input should be a valid list [type=list_type, input_value={'role': 'user', 'parts':...dings in simple words.'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/list_type
